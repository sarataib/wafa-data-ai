# %%
import pandas as pd

# Charger le CSV
df = pd.read_csv('market_data_with_indicators.csv')

# Sélectionner uniquement les colonnes Name et Ticker
instruments = df[['Name', 'Ticker']]

# Supprimer les doublons
unique_instruments = instruments.drop_duplicates()

# Afficher
print(unique_instruments)
# Out:
#                    Name Ticker
# 0     ATTIJARIWAFA BANK    ATW
# 744                BMCI    BCI
# 1488     BANK OF AFRICA    BOA
# 2232           CFG BANK    CFG
# 2722                CIH    CIH
# 3466       SANLAM MAROC    SAH
# 4210     WAFA ASSURANCE    WAA
